# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
folder = "log/grid_test_2/"
files = [f for f in os.listdir(folder) if f.endswith(".csv")]
files = sorted(files)
data = []
for file in files:
    data.append(np.genfromtxt(folder+file, delimiter=',',names = True))
print(len(data))
# Out:
# 30

# %%
interest = "accuracy"
for idx, d in enumerate(data):
    fig = plt.figure(idx)
    labels = [l for l in d.dtype.names if interest in l]
    for c in reversed(labels):
        plt.plot(d['epoch'], d[c], label = c)
    plt.legend()
    plt.title(files[idx][:-20])
# Out:
# <ipython-input-6-21d8f9dc90e0>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(idx)

# %%
matches = ["seq50_", "seq250_", "seq500_"]
for idx, d in enumerate(data):
    if any(x in files[idx] for x in matches):
        if "True" in files[idx]:
            plt.figure("Air", figsize = [10,5])
            plt.plot(d['epoch'], d['accuracy'], label = files[idx][11:-28])
            plt.legend()
            plt.ylabel("Accuracy")
            plt.xlabel("Epochs")
            plt.title("With Air-class")
        elif "False" in files[idx]:
            plt.figure("NoAir", figsize = [10,5])
            plt.plot(d['epoch'], d['accuracy'], label = files[idx][11:-28])
            plt.legend()
            plt.ylabel("Accuracy")
            plt.title("Without Air-class")
            plt.xlabel("Epochs")
